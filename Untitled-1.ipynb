# %%
import os
import pandas as pd


import torch
import torch.nn as nn
import torch.optim as optim


import torchvision
import torchvision.transforms as transforms

from torchvision.models import densenet121
from torch.utils.data import DataLoader, random_split


print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.enabled)
# Out:
# 2.2.0+cu121
# 12.1
# True

# %%
#KONIGURaCJa
# dataset:
# "CIFAR10"
# "CIFAR100"
DATASET_NAME = "CIFAR10"


BATCH_SIZE = 32
EPOCHS = 40
LEARNING_RATE = 0.01


MODEL_SAVE_PATH_CHECKPOINT = f"models/t_checkpoint_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
MODEL_SAVE_PATH = f"models/densenet_model_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
RESULTS_TO_EXCEL = "training_results.xlsx"
# EARLY STOPPING
PATIENCE = 5

# %%
#device
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("======================================")
print("DEVICE:", device)
print("======================================")
# Out:
# ======================================
# DEVICE: cuda
# ======================================

# %%
# TRANSFORMACJE

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(
    brightness=0.2,
    contrast=0.2,
    saturation=0.2),
    transforms.ToTensor(),
    transforms.RandomRotation(15),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# %%
# ============================================================
# DATASET
# ============================================================

if DATASET_NAME == "CIFAR10":

    NUM_CLASSES = 10

    full_train_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_train
    )

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

elif DATASET_NAME == "CIFAR100":

    NUM_CLASSES = 100

    full_train_dataset = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_train
    )

    test_dataset = torchvision.datasets.CIFAR100(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

else:
    raise ValueError("DATASET_NAME musi być CIFAR10 albo CIFAR100")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# ============================================================
# PODZIAŁ TRAIN / VALIDATION
# ============================================================

train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size

train_dataset, val_dataset = random_split(
    full_train_dataset,
    [train_size, val_size]
)

# %%
# DATALOADER
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# %%
# MODEL DENSENET121


# weights=None -> brak pretrained weights
model = densenet121(weights=None)

# zmiana pierwszej warstwy dla CIFAR
model.features.conv0 = nn.Conv2d(
    3, #licza kanałów wejściowych (RGB)
    64, # liczba kanałów wyjściowych (zgodna z oryginalnym modelem)
    kernel_size=3,# rozmiar filtra
    stride=1, #krok przesuwania filtra
    padding=1,#dodanie paddingu, żeby zachować rozmiar obrazu bo filtr 3x3 nie miesci sie
    bias=False
)

# usunięcie maxpool
model.features.pool0 = nn.Identity()

# zmiana klasyfikatora
model.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(  
    model.classifier.in_features,
    NUM_CLASSES)
)

model = model.to(device)

print("======================================")
print(model)
print("======================================")
# Out:
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# ======================================

# %%
# LOSS + OPTIMIZER


criterion = nn.CrossEntropyLoss() #funkcja bledu - porownuje przewidywania z prawdziwymi

# optimizer = optim.SGD(
#     model.parameters(),
#     lr=LEARNING_RATE,
#     momentum=0.9,
#     weight_decay=5e-4
# )
# optimizer = optim.Adam(
#     model.parameters(),
#     lr=LEARNING_RATE
# )
optimizer = optim.SGD(
    model.parameters(),
    lr=LEARNING_RATE,
    momentum=0.9,
    weight_decay=5e-4
)
# scheduler = optim.lr_scheduler.StepLR(
#     optimizer,
#     step_size=5,
#     gamma=0.1
# )


scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS
)

# %%
# ============================================================
# EARLY STOPPING VARIABLES
# ============================================================

best_val_loss = float("inf")
early_stop_counter = 0

# %%
#pętla treningowa


print("======================================")
print("START TRENINGU")
print("======================================")

for epoch in range(EPOCHS):

    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, (images, labels) in enumerate(train_loader):

        images = images.to(device)
        labels = labels.to(device)

        # zerowanie gradientów
        optimizer.zero_grad()

        # forward
        outputs = model(images)

        # loss
        loss = criterion(outputs, labels)

        # backward
        loss.backward() #liczenie gradientow

        # update wag
        optimizer.step()

        running_loss += loss.item()
        
        # accuracy train
        _, predicted = torch.max(outputs , 1)

        total_train += labels.size(0)

        correct_train += (predicted == labels).sum().item()
        
        # ====================================================
        # BATCH LOGGING
        # ====================================================

        if (batch_idx + 1) % 100 == 0:

            print(
                f"Epoch [{epoch+1}/{EPOCHS}] | "
                f"Batch [{batch_idx+1}/{len(train_loader)}] | "
                f"Batch Loss: {loss.item():.4f}"
            )

        
    # ========================================================
    # TRAIN METRICS
    # ========================================================

    train_loss = running_loss / len(train_loader)

    train_accuracy = 100 * correct_train / total_train
        
    # ========================================================
    # VALIDATION
    # ========================================================

    model.eval()

    running_val_loss = 0.0

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = criterion(outputs, labels)

            running_val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

    # ========================================================
    # VALIDATION METRICS
    # ========================================================

    val_loss = running_val_loss / len(val_loader)

    val_accuracy = 100 * correct / total

    # ========================================================
    # SCHEDULER STEP
    # ========================================================

    scheduler.step()
        

    # ========================================================
    # EPOCH LOGGING
    # ========================================================

    current_lr = optimizer.param_groups[0]["lr"]

    print("======================================")
    print(f"Epoch [{epoch+1}/{EPOCHS}] zakończona")
    print(f"Train Loss     : {train_loss:.4f}")
    print(f"Train Accuracy : {train_accuracy:.2f}%")
    print(f"Val Loss       : {val_loss:.4f}")
    print(f"Val Accuracy   : {val_accuracy:.2f}%")
    print(f"Learning Rate  : {current_lr}")
    print("======================================")

    # ========================================================
    # EARLY STOPPING
    # ========================================================

    if val_loss < best_val_loss:

        best_val_loss = val_loss
        early_stop_counter = 0

        torch.save(model.state_dict(), MODEL_SAVE_PATH)

        print("Najlepszy model zapisany.")

    else:

        early_stop_counter += 1

        print(f"Brak poprawy. Counter: {early_stop_counter}/{PATIENCE}")

    if early_stop_counter >= PATIENCE:

        print("======================================")
        print("EARLY STOPPING")
        print("======================================")
        break

print("======================================")
print("KONIEC TRENINGU")
print("======================================")

# ============================================================
# WCZYTANIE NAJLEPSZEGO MODELU
# ============================================================

model.load_state_dict(torch.load(MODEL_SAVE_PATH))
model.to(device)
# Out:
# ======================================
# START TRENINGU
# ======================================
# Epoch [1/40] | Batch [100/1250] | Batch Loss: 1.8612
# Epoch [1/40] | Batch [200/1250] | Batch Loss: 1.9663
# Epoch [1/40] | Batch [300/1250] | Batch Loss: 2.2225
# Epoch [1/40] | Batch [400/1250] | Batch Loss: 1.8216
# Epoch [1/40] | Batch [500/1250] | Batch Loss: 1.5987
# Epoch [1/40] | Batch [600/1250] | Batch Loss: 1.5654
# Epoch [1/40] | Batch [700/1250] | Batch Loss: 1.5044
# Epoch [1/40] | Batch [800/1250] | Batch Loss: 1.6342
# Epoch [1/40] | Batch [900/1250] | Batch Loss: 1.6194
# Epoch [1/40] | Batch [1000/1250] | Batch Loss: 1.1696
# Epoch [1/40] | Batch [1100/1250] | Batch Loss: 1.3111
# Epoch [1/40] | Batch [1200/1250] | Batch Loss: 0.9528
# ======================================
# Epoch [1/40] zakończona
# Train Loss     : 1.7060
# Train Accuracy : 38.60%
# Val Loss       : 1.5591
# Val Accuracy   : 46.01%
# Learning Rate  : 0.00998458666866564
# ======================================
# Najlepszy model zapisany.
# Epoch [2/40] | Batch [100/1250] | Batch Loss: 1.6133
# Epoch [2/40] | Batch [200/1250] | Batch Loss: 1.6042
# Epoch [2/40] | Batch [300/1250] | Batch Loss: 1.6307
# Epoch [2/40] | Batch [400/1250] | Batch Loss: 1.1211
# Epoch [2/40] | Batch [500/1250] | Batch Loss: 1.2590
# Epoch [2/40] | Batch [600/1250] | Batch Loss: 0.9365
# Epoch [2/40] | Batch [700/1250] | Batch Loss: 1.3155
# Epoch [2/40] | Batch [800/1250] | Batch Loss: 1.6381
# Epoch [2/40] | Batch [900/1250] | Batch Loss: 1.4949
# Epoch [2/40] | Batch [1000/1250] | Batch Loss: 1.0051
# Epoch [2/40] | Batch [1100/1250] | Batch Loss: 1.1370
# Epoch [2/40] | Batch [1200/1250] | Batch Loss: 0.9398
# ======================================
# Epoch [2/40] zakończona
# Train Loss     : 1.2399
# Train Accuracy : 56.09%
# Val Loss       : 1.1028
# Val Accuracy   : 61.20%
# Learning Rate  : 0.009938441702975689
# ======================================
# Najlepszy model zapisany.
# Epoch [3/40] | Batch [100/1250] | Batch Loss: 0.8468
# Epoch [3/40] | Batch [200/1250] | Batch Loss: 1.1596
# Epoch [3/40] | Batch [300/1250] | Batch Loss: 1.4025
# Epoch [3/40] | Batch [400/1250] | Batch Loss: 0.5022
# Epoch [3/40] | Batch [500/1250] | Batch Loss: 1.1955
# Epoch [3/40] | Batch [600/1250] | Batch Loss: 1.0261
# Epoch [3/40] | Batch [700/1250] | Batch Loss: 1.0584
# Epoch [3/40] | Batch [800/1250] | Batch Loss: 0.7811
# Epoch [3/40] | Batch [900/1250] | Batch Loss: 0.7361
# Epoch [3/40] | Batch [1000/1250] | Batch Loss: 1.1010
# Epoch [3/40] | Batch [1100/1250] | Batch Loss: 1.0515
# Epoch [3/40] | Batch [1200/1250] | Batch Loss: 0.9702
# ======================================
# Epoch [3/40] zakończona
# Train Loss     : 1.0157
# Train Accuracy : 64.33%
# Val Loss       : 0.9264
# Val Accuracy   : 68.67%
# Learning Rate  : 0.009861849601988383
# ======================================
# Najlepszy model zapisany.
# Epoch [4/40] | Batch [100/1250] | Batch Loss: 0.7088
# Epoch [4/40] | Batch [200/1250] | Batch Loss: 0.5780
# Epoch [4/40] | Batch [300/1250] | Batch Loss: 1.1803
# Epoch [4/40] | Batch [400/1250] | Batch Loss: 0.5176
# Epoch [4/40] | Batch [500/1250] | Batch Loss: 0.9724
# Epoch [4/40] | Batch [600/1250] | Batch Loss: 0.6409
# Epoch [4/40] | Batch [700/1250] | Batch Loss: 1.0787
# Epoch [4/40] | Batch [800/1250] | Batch Loss: 0.7371
# Epoch [4/40] | Batch [900/1250] | Batch Loss: 0.6601
# Epoch [4/40] | Batch [1000/1250] | Batch Loss: 0.7931
# Epoch [4/40] | Batch [1100/1250] | Batch Loss: 0.7583
# Epoch [4/40] | Batch [1200/1250] | Batch Loss: 0.9086
# ======================================
# Epoch [4/40] zakończona
# Train Loss     : 0.8533
# Train Accuracy : 70.18%
# Val Loss       : 0.7585
# Val Accuracy   : 73.45%
# Learning Rate  : 0.009755282581475769
# ======================================
# Najlepszy model zapisany.
# Epoch [5/40] | Batch [100/1250] | Batch Loss: 1.1791
# Epoch [5/40] | Batch [200/1250] | Batch Loss: 0.6131
# Epoch [5/40] | Batch [300/1250] | Batch Loss: 0.5425
# Epoch [5/40] | Batch [400/1250] | Batch Loss: 0.9431
# Epoch [5/40] | Batch [500/1250] | Batch Loss: 0.9325
# Epoch [5/40] | Batch [600/1250] | Batch Loss: 0.5631
# Epoch [5/40] | Batch [700/1250] | Batch Loss: 1.0680
# Epoch [5/40] | Batch [800/1250] | Batch Loss: 0.5858
# Epoch [5/40] | Batch [900/1250] | Batch Loss: 0.6423
# Epoch [5/40] | Batch [1000/1250] | Batch Loss: 0.8512
# Epoch [5/40] | Batch [1100/1250] | Batch Loss: 0.9856
# Epoch [5/40] | Batch [1200/1250] | Batch Loss: 0.6559
# ======================================
# Epoch [5/40] zakończona
# Train Loss     : 0.7446
# Train Accuracy : 74.14%
# Val Loss       : 0.7165
# Val Accuracy   : 74.65%
# Learning Rate  : 0.009619397662556435
# ======================================
# Najlepszy model zapisany.
# Epoch [6/40] | Batch [100/1250] | Batch Loss: 0.4867
# Epoch [6/40] | Batch [200/1250] | Batch Loss: 0.4771
# Epoch [6/40] | Batch [300/1250] | Batch Loss: 0.6173
# Epoch [6/40] | Batch [400/1250] | Batch Loss: 0.8638
# Epoch [6/40] | Batch [500/1250] | Batch Loss: 0.6521
# Epoch [6/40] | Batch [600/1250] | Batch Loss: 0.9810
# Epoch [6/40] | Batch [700/1250] | Batch Loss: 0.5517
# Epoch [6/40] | Batch [800/1250] | Batch Loss: 0.5839
# Epoch [6/40] | Batch [900/1250] | Batch Loss: 0.8134
# Epoch [6/40] | Batch [1000/1250] | Batch Loss: 0.7063
# Epoch [6/40] | Batch [1100/1250] | Batch Loss: 0.5491
# Epoch [6/40] | Batch [1200/1250] | Batch Loss: 0.4661
# ======================================
# Epoch [6/40] zakończona
# Train Loss     : 0.6656
# Train Accuracy : 76.88%
# Val Loss       : 0.6124
# Val Accuracy   : 79.01%
# Learning Rate  : 0.00945503262094184
# ======================================
# Najlepszy model zapisany.
# Epoch [7/40] | Batch [100/1250] | Batch Loss: 1.1309
# Epoch [7/40] | Batch [200/1250] | Batch Loss: 0.5321
# Epoch [7/40] | Batch [300/1250] | Batch Loss: 0.7271
# Epoch [7/40] | Batch [400/1250] | Batch Loss: 0.5152
# Epoch [7/40] | Batch [500/1250] | Batch Loss: 0.4906
# Epoch [7/40] | Batch [600/1250] | Batch Loss: 0.8121
# Epoch [7/40] | Batch [700/1250] | Batch Loss: 0.5686
# Epoch [7/40] | Batch [800/1250] | Batch Loss: 1.0191
# Epoch [7/40] | Batch [900/1250] | Batch Loss: 0.4421
# Epoch [7/40] | Batch [1000/1250] | Batch Loss: 0.3679
# Epoch [7/40] | Batch [1100/1250] | Batch Loss: 0.4519
# Epoch [7/40] | Batch [1200/1250] | Batch Loss: 0.5804
# ======================================
# Epoch [7/40] zakończona
# Train Loss     : 0.6103
# Train Accuracy : 78.96%
# Val Loss       : 0.5895
# Val Accuracy   : 79.56%
# Learning Rate  : 0.009263200821770462
# ======================================
# Najlepszy model zapisany.
# Epoch [8/40] | Batch [100/1250] | Batch Loss: 0.6539
# Epoch [8/40] | Batch [200/1250] | Batch Loss: 0.6753
# Epoch [8/40] | Batch [300/1250] | Batch Loss: 0.4802
# Epoch [8/40] | Batch [400/1250] | Batch Loss: 0.7124
# Epoch [8/40] | Batch [500/1250] | Batch Loss: 0.8971
# Epoch [8/40] | Batch [600/1250] | Batch Loss: 0.5139
# Epoch [8/40] | Batch [700/1250] | Batch Loss: 0.7516
# Epoch [8/40] | Batch [800/1250] | Batch Loss: 0.7426
# Epoch [8/40] | Batch [900/1250] | Batch Loss: 0.4955
# Epoch [8/40] | Batch [1000/1250] | Batch Loss: 0.5698
# Epoch [8/40] | Batch [1100/1250] | Batch Loss: 0.7343
# Epoch [8/40] | Batch [1200/1250] | Batch Loss: 0.4775
# ======================================
# Epoch [8/40] zakończona
# Train Loss     : 0.5633
# Train Accuracy : 80.72%
# Val Loss       : 0.5917
# Val Accuracy   : 79.63%
# Learning Rate  : 0.009045084971874739
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [9/40] | Batch [100/1250] | Batch Loss: 0.2788
# Epoch [9/40] | Batch [200/1250] | Batch Loss: 0.5338
# Epoch [9/40] | Batch [300/1250] | Batch Loss: 0.5383
# Epoch [9/40] | Batch [400/1250] | Batch Loss: 0.2062
# Epoch [9/40] | Batch [500/1250] | Batch Loss: 0.5885
# Epoch [9/40] | Batch [600/1250] | Batch Loss: 0.3564
# Epoch [9/40] | Batch [700/1250] | Batch Loss: 0.3224
# Epoch [9/40] | Batch [800/1250] | Batch Loss: 0.5545
# Epoch [9/40] | Batch [900/1250] | Batch Loss: 0.5184
# Epoch [9/40] | Batch [1000/1250] | Batch Loss: 0.6593
# Epoch [9/40] | Batch [1100/1250] | Batch Loss: 0.6563
# Epoch [9/40] | Batch [1200/1250] | Batch Loss: 0.7290
# ======================================
# Epoch [9/40] zakończona
# Train Loss     : 0.5261
# Train Accuracy : 81.83%
# Val Loss       : 0.5668
# Val Accuracy   : 80.57%
# Learning Rate  : 0.008802029828000156
# ======================================
# Najlepszy model zapisany.
# Epoch [10/40] | Batch [100/1250] | Batch Loss: 0.3831
# Epoch [10/40] | Batch [200/1250] | Batch Loss: 0.5461
# Epoch [10/40] | Batch [300/1250] | Batch Loss: 0.3369
# Epoch [10/40] | Batch [400/1250] | Batch Loss: 0.4241
# Epoch [10/40] | Batch [500/1250] | Batch Loss: 0.8106
# Epoch [10/40] | Batch [600/1250] | Batch Loss: 0.5415
# Epoch [10/40] | Batch [700/1250] | Batch Loss: 0.3868
# Epoch [10/40] | Batch [800/1250] | Batch Loss: 0.4709
# Epoch [10/40] | Batch [900/1250] | Batch Loss: 0.5852
# Epoch [10/40] | Batch [1000/1250] | Batch Loss: 0.7214
# Epoch [10/40] | Batch [1100/1250] | Batch Loss: 0.5492
# Epoch [10/40] | Batch [1200/1250] | Batch Loss: 0.5482
# ======================================
# Epoch [10/40] zakończona
# Train Loss     : 0.4983
# Train Accuracy : 82.94%
# Val Loss       : 0.5028
# Val Accuracy   : 82.71%
# Learning Rate  : 0.008535533905932738
# ======================================
# Najlepszy model zapisany.
# Epoch [11/40] | Batch [100/1250] | Batch Loss: 0.5559
# Epoch [11/40] | Batch [200/1250] | Batch Loss: 0.6554
# Epoch [11/40] | Batch [300/1250] | Batch Loss: 0.3360
# Epoch [11/40] | Batch [400/1250] | Batch Loss: 0.7822
# Epoch [11/40] | Batch [500/1250] | Batch Loss: 0.2960
# Epoch [11/40] | Batch [600/1250] | Batch Loss: 0.5496
# Epoch [11/40] | Batch [700/1250] | Batch Loss: 0.4536
# Epoch [11/40] | Batch [800/1250] | Batch Loss: 0.5423
# Epoch [11/40] | Batch [900/1250] | Batch Loss: 0.3903
# Epoch [11/40] | Batch [1000/1250] | Batch Loss: 0.3939
# Epoch [11/40] | Batch [1100/1250] | Batch Loss: 0.4290
# Epoch [11/40] | Batch [1200/1250] | Batch Loss: 0.7228
# ======================================
# Epoch [11/40] zakończona
# Train Loss     : 0.4688
# Train Accuracy : 83.89%
# Val Loss       : 0.4845
# Val Accuracy   : 83.36%
# Learning Rate  : 0.00824724024165092
# ======================================
# Najlepszy model zapisany.
# Epoch [12/40] | Batch [100/1250] | Batch Loss: 0.6603
# Epoch [12/40] | Batch [200/1250] | Batch Loss: 0.4843
# Epoch [12/40] | Batch [300/1250] | Batch Loss: 0.6292
# Epoch [12/40] | Batch [400/1250] | Batch Loss: 0.4035
# Epoch [12/40] | Batch [500/1250] | Batch Loss: 0.6394
# Epoch [12/40] | Batch [600/1250] | Batch Loss: 0.7781
# Epoch [12/40] | Batch [700/1250] | Batch Loss: 0.3771
# Epoch [12/40] | Batch [800/1250] | Batch Loss: 0.6919
# Epoch [12/40] | Batch [900/1250] | Batch Loss: 0.4807
# Epoch [12/40] | Batch [1000/1250] | Batch Loss: 0.2617
# Epoch [12/40] | Batch [1100/1250] | Batch Loss: 0.6698
# Epoch [12/40] | Batch [1200/1250] | Batch Loss: 0.3371
# ======================================
# Epoch [12/40] zakończona
# Train Loss     : 0.4429
# Train Accuracy : 84.65%
# Val Loss       : 0.4529
# Val Accuracy   : 84.06%
# Learning Rate  : 0.007938926261462366
# ======================================
# Najlepszy model zapisany.
# Epoch [13/40] | Batch [100/1250] | Batch Loss: 0.3085
# Epoch [13/40] | Batch [200/1250] | Batch Loss: 0.5548
# Epoch [13/40] | Batch [300/1250] | Batch Loss: 0.3184
# Epoch [13/40] | Batch [400/1250] | Batch Loss: 0.2556
# Epoch [13/40] | Batch [500/1250] | Batch Loss: 0.3081
# Epoch [13/40] | Batch [600/1250] | Batch Loss: 0.2681
# Epoch [13/40] | Batch [700/1250] | Batch Loss: 0.3521
# Epoch [13/40] | Batch [800/1250] | Batch Loss: 0.8169
# Epoch [13/40] | Batch [900/1250] | Batch Loss: 0.2470
# Epoch [13/40] | Batch [1000/1250] | Batch Loss: 0.4365
# Epoch [13/40] | Batch [1100/1250] | Batch Loss: 0.4820
# Epoch [13/40] | Batch [1200/1250] | Batch Loss: 0.1998
# ======================================
# Epoch [13/40] zakończona
# Train Loss     : 0.4207
# Train Accuracy : 85.64%
# Val Loss       : 0.4699
# Val Accuracy   : 83.47%
# Learning Rate  : 0.0076124928235797445
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [14/40] | Batch [100/1250] | Batch Loss: 0.5275
# Epoch [14/40] | Batch [200/1250] | Batch Loss: 0.4454
# Epoch [14/40] | Batch [300/1250] | Batch Loss: 0.2339
# Epoch [14/40] | Batch [400/1250] | Batch Loss: 0.5448
# Epoch [14/40] | Batch [500/1250] | Batch Loss: 0.1527
# Epoch [14/40] | Batch [600/1250] | Batch Loss: 0.2666
# Epoch [14/40] | Batch [700/1250] | Batch Loss: 0.3265
# Epoch [14/40] | Batch [800/1250] | Batch Loss: 0.2538
# Epoch [14/40] | Batch [900/1250] | Batch Loss: 0.2591
# Epoch [14/40] | Batch [1000/1250] | Batch Loss: 0.2662
# Epoch [14/40] | Batch [1100/1250] | Batch Loss: 0.7643
# Epoch [14/40] | Batch [1200/1250] | Batch Loss: 0.1745
# ======================================
# Epoch [14/40] zakończona
# Train Loss     : 0.3968
# Train Accuracy : 86.41%
# Val Loss       : 0.4841
# Val Accuracy   : 83.61%
# Learning Rate  : 0.007269952498697735
# ======================================
# Brak poprawy. Counter: 2/5
# Epoch [15/40] | Batch [100/1250] | Batch Loss: 0.4821
# Epoch [15/40] | Batch [200/1250] | Batch Loss: 0.2642
# Epoch [15/40] | Batch [300/1250] | Batch Loss: 0.2196
# Epoch [15/40] | Batch [400/1250] | Batch Loss: 0.3235
# Epoch [15/40] | Batch [500/1250] | Batch Loss: 0.3637
# Epoch [15/40] | Batch [600/1250] | Batch Loss: 0.5118
# Epoch [15/40] | Batch [700/1250] | Batch Loss: 0.3299
# Epoch [15/40] | Batch [800/1250] | Batch Loss: 0.7008
# Epoch [15/40] | Batch [900/1250] | Batch Loss: 0.2409
# Epoch [15/40] | Batch [1000/1250] | Batch Loss: 0.4876
# Epoch [15/40] | Batch [1100/1250] | Batch Loss: 0.2837
# Epoch [15/40] | Batch [1200/1250] | Batch Loss: 0.4500
# ======================================
# Epoch [15/40] zakończona
# Train Loss     : 0.3851
# Train Accuracy : 86.75%
# Val Loss       : 0.4217
# Val Accuracy   : 85.81%
# Learning Rate  : 0.0069134171618254504
# ======================================
# Najlepszy model zapisany.
# Epoch [16/40] | Batch [100/1250] | Batch Loss: 0.3504
# Epoch [16/40] | Batch [200/1250] | Batch Loss: 0.5443
# Epoch [16/40] | Batch [300/1250] | Batch Loss: 0.2685
# Epoch [16/40] | Batch [400/1250] | Batch Loss: 0.3870
# Epoch [16/40] | Batch [500/1250] | Batch Loss: 0.1997
# Epoch [16/40] | Batch [600/1250] | Batch Loss: 0.5651
# Epoch [16/40] | Batch [700/1250] | Batch Loss: 0.3468
# Epoch [16/40] | Batch [800/1250] | Batch Loss: 0.4931
# Epoch [16/40] | Batch [900/1250] | Batch Loss: 0.3529
# Epoch [16/40] | Batch [1000/1250] | Batch Loss: 0.3244
# Epoch [16/40] | Batch [1100/1250] | Batch Loss: 0.1908
# Epoch [16/40] | Batch [1200/1250] | Batch Loss: 0.2290
# ======================================
# Epoch [16/40] zakończona
# Train Loss     : 0.3662
# Train Accuracy : 87.25%
# Val Loss       : 0.4298
# Val Accuracy   : 85.41%
# Learning Rate  : 0.006545084971874739
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [17/40] | Batch [100/1250] | Batch Loss: 0.2852
# Epoch [17/40] | Batch [200/1250] | Batch Loss: 0.4041
# Epoch [17/40] | Batch [300/1250] | Batch Loss: 0.3482
# Epoch [17/40] | Batch [400/1250] | Batch Loss: 0.2870
# Epoch [17/40] | Batch [500/1250] | Batch Loss: 0.1675
# Epoch [17/40] | Batch [600/1250] | Batch Loss: 0.3532
# Epoch [17/40] | Batch [700/1250] | Batch Loss: 0.3343
# Epoch [17/40] | Batch [800/1250] | Batch Loss: 0.2249
# Epoch [17/40] | Batch [900/1250] | Batch Loss: 0.3532
# Epoch [17/40] | Batch [1000/1250] | Batch Loss: 0.3505
# Epoch [17/40] | Batch [1100/1250] | Batch Loss: 0.5636
# Epoch [17/40] | Batch [1200/1250] | Batch Loss: 0.7038
# ======================================
# Epoch [17/40] zakończona
# Train Loss     : 0.3499
# Train Accuracy : 87.97%
# Val Loss       : 0.4019
# Val Accuracy   : 86.21%
# Learning Rate  : 0.006167226819279529
# ======================================
# Najlepszy model zapisany.
# Epoch [18/40] | Batch [100/1250] | Batch Loss: 0.1005
# Epoch [18/40] | Batch [200/1250] | Batch Loss: 0.2739
# Epoch [18/40] | Batch [300/1250] | Batch Loss: 0.4725
# Epoch [18/40] | Batch [400/1250] | Batch Loss: 0.3343
# Epoch [18/40] | Batch [500/1250] | Batch Loss: 0.2635
# Epoch [18/40] | Batch [600/1250] | Batch Loss: 0.2271
# Epoch [18/40] | Batch [700/1250] | Batch Loss: 0.1753
# Epoch [18/40] | Batch [800/1250] | Batch Loss: 0.2269
# Epoch [18/40] | Batch [900/1250] | Batch Loss: 0.6566
# Epoch [18/40] | Batch [1000/1250] | Batch Loss: 0.3229
# Epoch [18/40] | Batch [1100/1250] | Batch Loss: 0.6056
# Epoch [18/40] | Batch [1200/1250] | Batch Loss: 0.1766
# ======================================
# Epoch [18/40] zakończona
# Train Loss     : 0.3315
# Train Accuracy : 88.59%
# Val Loss       : 0.4216
# Val Accuracy   : 85.45%
# Learning Rate  : 0.005782172325201156
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [19/40] | Batch [100/1250] | Batch Loss: 0.3474
# Epoch [19/40] | Batch [200/1250] | Batch Loss: 0.7001
# Epoch [19/40] | Batch [300/1250] | Batch Loss: 0.1803
# Epoch [19/40] | Batch [400/1250] | Batch Loss: 0.3160
# Epoch [19/40] | Batch [500/1250] | Batch Loss: 0.3086
# Epoch [19/40] | Batch [600/1250] | Batch Loss: 0.3740
# Epoch [19/40] | Batch [700/1250] | Batch Loss: 0.4784
# Epoch [19/40] | Batch [800/1250] | Batch Loss: 0.2638
# Epoch [19/40] | Batch [900/1250] | Batch Loss: 0.4861
# Epoch [19/40] | Batch [1000/1250] | Batch Loss: 0.1163
# Epoch [19/40] | Batch [1100/1250] | Batch Loss: 0.1671
# Epoch [19/40] | Batch [1200/1250] | Batch Loss: 0.2962
# ======================================
# Epoch [19/40] zakończona
# Train Loss     : 0.3121
# Train Accuracy : 89.23%
# Val Loss       : 0.3794
# Val Accuracy   : 87.44%
# Learning Rate  : 0.005392295478639226
# ======================================
# Najlepszy model zapisany.
# Epoch [20/40] | Batch [100/1250] | Batch Loss: 0.5526
# Epoch [20/40] | Batch [200/1250] | Batch Loss: 0.2257
# Epoch [20/40] | Batch [300/1250] | Batch Loss: 0.5489
# Epoch [20/40] | Batch [400/1250] | Batch Loss: 0.1317
# Epoch [20/40] | Batch [500/1250] | Batch Loss: 0.3918
# Epoch [20/40] | Batch [600/1250] | Batch Loss: 0.2645
# Epoch [20/40] | Batch [700/1250] | Batch Loss: 0.4007
# Epoch [20/40] | Batch [800/1250] | Batch Loss: 0.2458
# Epoch [20/40] | Batch [900/1250] | Batch Loss: 0.1929
# Epoch [20/40] | Batch [1000/1250] | Batch Loss: 0.1836
# Epoch [20/40] | Batch [1100/1250] | Batch Loss: 0.2542
# Epoch [20/40] | Batch [1200/1250] | Batch Loss: 0.1922
# ======================================
# Epoch [20/40] zakończona
# Train Loss     : 0.2914
# Train Accuracy : 90.05%
# Val Loss       : 0.3907
# Val Accuracy   : 87.28%
# Learning Rate  : 0.005000000000000001
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [21/40] | Batch [100/1250] | Batch Loss: 0.1963
# Epoch [21/40] | Batch [200/1250] | Batch Loss: 0.2286
# Epoch [21/40] | Batch [300/1250] | Batch Loss: 0.6463
# Epoch [21/40] | Batch [400/1250] | Batch Loss: 0.1802
# Epoch [21/40] | Batch [500/1250] | Batch Loss: 0.5630
# Epoch [21/40] | Batch [600/1250] | Batch Loss: 0.2478
# Epoch [21/40] | Batch [700/1250] | Batch Loss: 0.3303
# Epoch [21/40] | Batch [800/1250] | Batch Loss: 0.1418
# Epoch [21/40] | Batch [900/1250] | Batch Loss: 0.2850
# Epoch [21/40] | Batch [1000/1250] | Batch Loss: 0.4270
# Epoch [21/40] | Batch [1100/1250] | Batch Loss: 0.3897
# Epoch [21/40] | Batch [1200/1250] | Batch Loss: 0.1201
# ======================================
# Epoch [21/40] zakończona
# Train Loss     : 0.2814
# Train Accuracy : 90.31%
# Val Loss       : 0.3576
# Val Accuracy   : 87.60%
# Learning Rate  : 0.004607704521360776
# ======================================
# Najlepszy model zapisany.
# Epoch [22/40] | Batch [100/1250] | Batch Loss: 0.0876
# Epoch [22/40] | Batch [200/1250] | Batch Loss: 0.1250
# Epoch [22/40] | Batch [300/1250] | Batch Loss: 0.2312
# Epoch [22/40] | Batch [400/1250] | Batch Loss: 0.3840
# Epoch [22/40] | Batch [500/1250] | Batch Loss: 0.2068
# Epoch [22/40] | Batch [600/1250] | Batch Loss: 0.0941
# Epoch [22/40] | Batch [700/1250] | Batch Loss: 0.2331
# Epoch [22/40] | Batch [800/1250] | Batch Loss: 0.1829
# Epoch [22/40] | Batch [900/1250] | Batch Loss: 0.2920
# Epoch [22/40] | Batch [1000/1250] | Batch Loss: 0.4683
# Epoch [22/40] | Batch [1100/1250] | Batch Loss: 0.3052
# Epoch [22/40] | Batch [1200/1250] | Batch Loss: 0.4499
# ======================================
# Epoch [22/40] zakończona
# Train Loss     : 0.2631
# Train Accuracy : 90.88%
# Val Loss       : 0.3472
# Val Accuracy   : 88.22%
# Learning Rate  : 0.004217827674798847
# ======================================
# Najlepszy model zapisany.
# Epoch [23/40] | Batch [100/1250] | Batch Loss: 0.0774
# Epoch [23/40] | Batch [200/1250] | Batch Loss: 0.3746
# Epoch [23/40] | Batch [300/1250] | Batch Loss: 0.3331
# Epoch [23/40] | Batch [400/1250] | Batch Loss: 0.2148
# Epoch [23/40] | Batch [500/1250] | Batch Loss: 0.2088
# Epoch [23/40] | Batch [600/1250] | Batch Loss: 0.3274
# Epoch [23/40] | Batch [700/1250] | Batch Loss: 0.1911
# Epoch [23/40] | Batch [800/1250] | Batch Loss: 0.0663
# Epoch [23/40] | Batch [900/1250] | Batch Loss: 0.3285
# Epoch [23/40] | Batch [1000/1250] | Batch Loss: 0.2820
# Epoch [23/40] | Batch [1100/1250] | Batch Loss: 0.1157
# Epoch [23/40] | Batch [1200/1250] | Batch Loss: 0.3201
# ======================================
# Epoch [23/40] zakończona
# Train Loss     : 0.2415
# Train Accuracy : 91.67%
# Val Loss       : 0.3756
# Val Accuracy   : 87.34%
# Learning Rate  : 0.0038327731807204736
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [24/40] | Batch [100/1250] | Batch Loss: 0.1998
# Epoch [24/40] | Batch [200/1250] | Batch Loss: 0.1664
# Epoch [24/40] | Batch [300/1250] | Batch Loss: 0.3388
# Epoch [24/40] | Batch [400/1250] | Batch Loss: 0.6259
# Epoch [24/40] | Batch [500/1250] | Batch Loss: 0.1034
# Epoch [24/40] | Batch [600/1250] | Batch Loss: 0.3357
# Epoch [24/40] | Batch [700/1250] | Batch Loss: 0.1336
# Epoch [24/40] | Batch [800/1250] | Batch Loss: 0.0535
# Epoch [24/40] | Batch [900/1250] | Batch Loss: 0.2596
# Epoch [24/40] | Batch [1000/1250] | Batch Loss: 0.2231
# Epoch [24/40] | Batch [1100/1250] | Batch Loss: 0.0802
# Epoch [24/40] | Batch [1200/1250] | Batch Loss: 0.2409
# ======================================
# Epoch [24/40] zakończona
# Train Loss     : 0.2283
# Train Accuracy : 92.19%
# Val Loss       : 0.3172
# Val Accuracy   : 89.54%
# Learning Rate  : 0.003454915028125263
# ======================================
# Najlepszy model zapisany.
# Epoch [25/40] | Batch [100/1250] | Batch Loss: 0.2531
# Epoch [25/40] | Batch [200/1250] | Batch Loss: 0.1482
# Epoch [25/40] | Batch [300/1250] | Batch Loss: 0.2250
# Epoch [25/40] | Batch [400/1250] | Batch Loss: 0.2051
# Epoch [25/40] | Batch [500/1250] | Batch Loss: 0.0946
# Epoch [25/40] | Batch [600/1250] | Batch Loss: 0.3814
# Epoch [25/40] | Batch [700/1250] | Batch Loss: 0.1052
# Epoch [25/40] | Batch [800/1250] | Batch Loss: 0.1179
# Epoch [25/40] | Batch [900/1250] | Batch Loss: 0.1240
# Epoch [25/40] | Batch [1000/1250] | Batch Loss: 0.0504
# Epoch [25/40] | Batch [1100/1250] | Batch Loss: 0.3654
# Epoch [25/40] | Batch [1200/1250] | Batch Loss: 0.2013
# ======================================
# Epoch [25/40] zakończona
# Train Loss     : 0.2141
# Train Accuracy : 92.83%
# Val Loss       : 0.3298
# Val Accuracy   : 89.12%
# Learning Rate  : 0.0030865828381745515
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [26/40] | Batch [100/1250] | Batch Loss: 0.2277
# Epoch [26/40] | Batch [200/1250] | Batch Loss: 0.1888
# Epoch [26/40] | Batch [300/1250] | Batch Loss: 0.2321
# Epoch [26/40] | Batch [400/1250] | Batch Loss: 0.1394
# Epoch [26/40] | Batch [500/1250] | Batch Loss: 0.1381
# Epoch [26/40] | Batch [600/1250] | Batch Loss: 0.0973
# Epoch [26/40] | Batch [700/1250] | Batch Loss: 0.0752
# Epoch [26/40] | Batch [800/1250] | Batch Loss: 0.1957
# Epoch [26/40] | Batch [900/1250] | Batch Loss: 0.3149
# Epoch [26/40] | Batch [1000/1250] | Batch Loss: 0.2093
# Epoch [26/40] | Batch [1100/1250] | Batch Loss: 0.1733
# Epoch [26/40] | Batch [1200/1250] | Batch Loss: 0.0680
# ======================================
# Epoch [26/40] zakończona
# Train Loss     : 0.1959
# Train Accuracy : 93.30%
# Val Loss       : 0.3395
# Val Accuracy   : 88.44%
# Learning Rate  : 0.0027300475013022664
# ======================================
# Brak poprawy. Counter: 2/5
# Epoch [27/40] | Batch [100/1250] | Batch Loss: 0.1404
# Epoch [27/40] | Batch [200/1250] | Batch Loss: 0.1013
# Epoch [27/40] | Batch [300/1250] | Batch Loss: 0.1324
# Epoch [27/40] | Batch [400/1250] | Batch Loss: 0.0623
# Epoch [27/40] | Batch [500/1250] | Batch Loss: 0.1986
# Epoch [27/40] | Batch [600/1250] | Batch Loss: 0.1591
# Epoch [27/40] | Batch [700/1250] | Batch Loss: 0.1391
# Epoch [27/40] | Batch [800/1250] | Batch Loss: 0.0441
# Epoch [27/40] | Batch [900/1250] | Batch Loss: 0.0696
# Epoch [27/40] | Batch [1000/1250] | Batch Loss: 0.0934
# Epoch [27/40] | Batch [1100/1250] | Batch Loss: 0.1970
# Epoch [27/40] | Batch [1200/1250] | Batch Loss: 0.1361
# ======================================
# Epoch [27/40] zakończona
# Train Loss     : 0.1751
# Train Accuracy : 94.03%
# Val Loss       : 0.3080
# Val Accuracy   : 89.47%
# Learning Rate  : 0.002387507176420256
# ======================================
# Najlepszy model zapisany.
# Epoch [28/40] | Batch [100/1250] | Batch Loss: 0.0641
# Epoch [28/40] | Batch [200/1250] | Batch Loss: 0.0823
# Epoch [28/40] | Batch [300/1250] | Batch Loss: 0.2506
# Epoch [28/40] | Batch [400/1250] | Batch Loss: 0.1280
# Epoch [28/40] | Batch [500/1250] | Batch Loss: 0.1020
# Epoch [28/40] | Batch [600/1250] | Batch Loss: 0.2407
# Epoch [28/40] | Batch [700/1250] | Batch Loss: 0.1841
# Epoch [28/40] | Batch [800/1250] | Batch Loss: 0.1446
# Epoch [28/40] | Batch [900/1250] | Batch Loss: 0.1264
# Epoch [28/40] | Batch [1000/1250] | Batch Loss: 0.1211
# Epoch [28/40] | Batch [1100/1250] | Batch Loss: 0.0451
# Epoch [28/40] | Batch [1200/1250] | Batch Loss: 0.0914
# ======================================
# Epoch [28/40] zakończona
# Train Loss     : 0.1592
# Train Accuracy : 94.60%
# Val Loss       : 0.3082
# Val Accuracy   : 89.99%
# Learning Rate  : 0.002061073738537635
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [29/40] | Batch [100/1250] | Batch Loss: 0.0404
# Epoch [29/40] | Batch [200/1250] | Batch Loss: 0.0715
# Epoch [29/40] | Batch [300/1250] | Batch Loss: 0.2309
# Epoch [29/40] | Batch [400/1250] | Batch Loss: 0.1596
# Epoch [29/40] | Batch [500/1250] | Batch Loss: 0.1430
# Epoch [29/40] | Batch [600/1250] | Batch Loss: 0.3900
# Epoch [29/40] | Batch [700/1250] | Batch Loss: 0.1125
# Epoch [29/40] | Batch [800/1250] | Batch Loss: 0.0386
# Epoch [29/40] | Batch [900/1250] | Batch Loss: 0.1485
# Epoch [29/40] | Batch [1000/1250] | Batch Loss: 0.4492
# Epoch [29/40] | Batch [1100/1250] | Batch Loss: 0.0966
# Epoch [29/40] | Batch [1200/1250] | Batch Loss: 0.0906
# ======================================
# Epoch [29/40] zakończona
# Train Loss     : 0.1432
# Train Accuracy : 95.09%
# Val Loss       : 0.3023
# Val Accuracy   : 89.99%
# Learning Rate  : 0.0017527597583490825
# ======================================
# Najlepszy model zapisany.
# Epoch [30/40] | Batch [100/1250] | Batch Loss: 0.1649
# Epoch [30/40] | Batch [200/1250] | Batch Loss: 0.0759
# Epoch [30/40] | Batch [300/1250] | Batch Loss: 0.2496
# Epoch [30/40] | Batch [400/1250] | Batch Loss: 0.1271
# Epoch [30/40] | Batch [500/1250] | Batch Loss: 0.2166
# Epoch [30/40] | Batch [600/1250] | Batch Loss: 0.0881
# Epoch [30/40] | Batch [700/1250] | Batch Loss: 0.0615
# Epoch [30/40] | Batch [800/1250] | Batch Loss: 0.0983
# Epoch [30/40] | Batch [900/1250] | Batch Loss: 0.0417
# Epoch [30/40] | Batch [1000/1250] | Batch Loss: 0.1945
# Epoch [30/40] | Batch [1100/1250] | Batch Loss: 0.0508
# Epoch [30/40] | Batch [1200/1250] | Batch Loss: 0.1360
# ======================================
# Epoch [30/40] zakończona
# Train Loss     : 0.1282
# Train Accuracy : 95.69%
# Val Loss       : 0.3051
# Val Accuracy   : 90.02%
# Learning Rate  : 0.0014644660940672629
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [31/40] | Batch [100/1250] | Batch Loss: 0.0789
# Epoch [31/40] | Batch [200/1250] | Batch Loss: 0.0189
# Epoch [31/40] | Batch [300/1250] | Batch Loss: 0.1012
# Epoch [31/40] | Batch [400/1250] | Batch Loss: 0.1413
# Epoch [31/40] | Batch [500/1250] | Batch Loss: 0.1127
# Epoch [31/40] | Batch [600/1250] | Batch Loss: 0.1293
# Epoch [31/40] | Batch [700/1250] | Batch Loss: 0.0470
# Epoch [31/40] | Batch [800/1250] | Batch Loss: 0.0658
# Epoch [31/40] | Batch [900/1250] | Batch Loss: 0.1450
# Epoch [31/40] | Batch [1000/1250] | Batch Loss: 0.0700
# Epoch [31/40] | Batch [1100/1250] | Batch Loss: 0.1109
# Epoch [31/40] | Batch [1200/1250] | Batch Loss: 0.1406
# ======================================
# Epoch [31/40] zakończona
# Train Loss     : 0.1159
# Train Accuracy : 96.14%
# Val Loss       : 0.2893
# Val Accuracy   : 90.82%
# Learning Rate  : 0.0011979701719998454
# ======================================
# Najlepszy model zapisany.
# Epoch [32/40] | Batch [100/1250] | Batch Loss: 0.0586
# Epoch [32/40] | Batch [200/1250] | Batch Loss: 0.1362
# Epoch [32/40] | Batch [300/1250] | Batch Loss: 0.0725
# Epoch [32/40] | Batch [400/1250] | Batch Loss: 0.1675
# Epoch [32/40] | Batch [500/1250] | Batch Loss: 0.0752
# Epoch [32/40] | Batch [600/1250] | Batch Loss: 0.0491
# Epoch [32/40] | Batch [700/1250] | Batch Loss: 0.1387
# Epoch [32/40] | Batch [800/1250] | Batch Loss: 0.1457
# Epoch [32/40] | Batch [900/1250] | Batch Loss: 0.0882
# Epoch [32/40] | Batch [1000/1250] | Batch Loss: 0.1284
# Epoch [32/40] | Batch [1100/1250] | Batch Loss: 0.0817
# Epoch [32/40] | Batch [1200/1250] | Batch Loss: 0.0594
# ======================================
# Epoch [32/40] zakończona
# Train Loss     : 0.1022
# Train Accuracy : 96.58%
# Val Loss       : 0.2774
# Val Accuracy   : 91.10%
# Learning Rate  : 0.0009549150281252633
# ======================================
# Najlepszy model zapisany.
# Epoch [33/40] | Batch [100/1250] | Batch Loss: 0.1152
# Epoch [33/40] | Batch [200/1250] | Batch Loss: 0.0839
# Epoch [33/40] | Batch [300/1250] | Batch Loss: 0.0368
# Epoch [33/40] | Batch [400/1250] | Batch Loss: 0.0506
# Epoch [33/40] | Batch [500/1250] | Batch Loss: 0.0628
# Epoch [33/40] | Batch [600/1250] | Batch Loss: 0.0795
# Epoch [33/40] | Batch [700/1250] | Batch Loss: 0.1777
# Epoch [33/40] | Batch [800/1250] | Batch Loss: 0.0457
# Epoch [33/40] | Batch [900/1250] | Batch Loss: 0.0258
# Epoch [33/40] | Batch [1000/1250] | Batch Loss: 0.0569
# Epoch [33/40] | Batch [1100/1250] | Batch Loss: 0.0371
# Epoch [33/40] | Batch [1200/1250] | Batch Loss: 0.0324
# ======================================
# Epoch [33/40] zakończona
# Train Loss     : 0.0871
# Train Accuracy : 97.17%
# Val Loss       : 0.2723
# Val Accuracy   : 91.47%
# Learning Rate  : 0.0007367991782295391
# ======================================
# Najlepszy model zapisany.
# Epoch [34/40] | Batch [100/1250] | Batch Loss: 0.1956
# Epoch [34/40] | Batch [200/1250] | Batch Loss: 0.0548
# Epoch [34/40] | Batch [300/1250] | Batch Loss: 0.0962
# Epoch [34/40] | Batch [400/1250] | Batch Loss: 0.0361
# Epoch [34/40] | Batch [500/1250] | Batch Loss: 0.0196
# Epoch [34/40] | Batch [600/1250] | Batch Loss: 0.2823
# Epoch [34/40] | Batch [700/1250] | Batch Loss: 0.0316
# Epoch [34/40] | Batch [800/1250] | Batch Loss: 0.0228
# Epoch [34/40] | Batch [900/1250] | Batch Loss: 0.0636
# Epoch [34/40] | Batch [1000/1250] | Batch Loss: 0.1629
# Epoch [34/40] | Batch [1100/1250] | Batch Loss: 0.0705
# Epoch [34/40] | Batch [1200/1250] | Batch Loss: 0.0917
# ======================================
# Epoch [34/40] zakończona
# Train Loss     : 0.0753
# Train Accuracy : 97.61%
# Val Loss       : 0.2668
# Val Accuracy   : 91.72%
# Learning Rate  : 0.0005449673790581611
# ======================================
# Najlepszy model zapisany.
# Epoch [35/40] | Batch [100/1250] | Batch Loss: 0.2379
# Epoch [35/40] | Batch [200/1250] | Batch Loss: 0.0844
# Epoch [35/40] | Batch [300/1250] | Batch Loss: 0.0646
# Epoch [35/40] | Batch [400/1250] | Batch Loss: 0.0247
# Epoch [35/40] | Batch [500/1250] | Batch Loss: 0.0118
# Epoch [35/40] | Batch [600/1250] | Batch Loss: 0.0127
# Epoch [35/40] | Batch [700/1250] | Batch Loss: 0.0560
# Epoch [35/40] | Batch [800/1250] | Batch Loss: 0.0351
# Epoch [35/40] | Batch [900/1250] | Batch Loss: 0.0112
# Epoch [35/40] | Batch [1000/1250] | Batch Loss: 0.1293
# Epoch [35/40] | Batch [1100/1250] | Batch Loss: 0.0215
# Epoch [35/40] | Batch [1200/1250] | Batch Loss: 0.2082
# ======================================
# Epoch [35/40] zakończona
# Train Loss     : 0.0673
# Train Accuracy : 97.84%
# Val Loss       : 0.2679
# Val Accuracy   : 91.71%
# Learning Rate  : 0.0003806023374435663
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [36/40] | Batch [100/1250] | Batch Loss: 0.0193
# Epoch [36/40] | Batch [200/1250] | Batch Loss: 0.0316
# Epoch [36/40] | Batch [300/1250] | Batch Loss: 0.0208
# Epoch [36/40] | Batch [400/1250] | Batch Loss: 0.1101
# Epoch [36/40] | Batch [500/1250] | Batch Loss: 0.0248
# Epoch [36/40] | Batch [600/1250] | Batch Loss: 0.1987
# Epoch [36/40] | Batch [700/1250] | Batch Loss: 0.1283
# Epoch [36/40] | Batch [800/1250] | Batch Loss: 0.0390
# Epoch [36/40] | Batch [900/1250] | Batch Loss: 0.0330
# Epoch [36/40] | Batch [1000/1250] | Batch Loss: 0.0903
# Epoch [36/40] | Batch [1100/1250] | Batch Loss: 0.0563
# Epoch [36/40] | Batch [1200/1250] | Batch Loss: 0.0544
# ======================================
# Epoch [36/40] zakończona
# Train Loss     : 0.0624
# Train Accuracy : 98.03%
# Val Loss       : 0.2665
# Val Accuracy   : 91.66%
# Learning Rate  : 0.00024471741852423234
# ======================================
# Najlepszy model zapisany.
# Epoch [37/40] | Batch [100/1250] | Batch Loss: 0.0208
# Epoch [37/40] | Batch [200/1250] | Batch Loss: 0.0760
# Epoch [37/40] | Batch [300/1250] | Batch Loss: 0.0179
# Epoch [37/40] | Batch [400/1250] | Batch Loss: 0.0063
# Epoch [37/40] | Batch [500/1250] | Batch Loss: 0.0481
# Epoch [37/40] | Batch [600/1250] | Batch Loss: 0.1052
# Epoch [37/40] | Batch [700/1250] | Batch Loss: 0.0379
# Epoch [37/40] | Batch [800/1250] | Batch Loss: 0.0918
# Epoch [37/40] | Batch [900/1250] | Batch Loss: 0.0050
# Epoch [37/40] | Batch [1000/1250] | Batch Loss: 0.1773
# Epoch [37/40] | Batch [1100/1250] | Batch Loss: 0.0914
# Epoch [37/40] | Batch [1200/1250] | Batch Loss: 0.0109
# ======================================
# Epoch [37/40] zakończona
# Train Loss     : 0.0554
# Train Accuracy : 98.25%
# Val Loss       : 0.2743
# Val Accuracy   : 91.68%
# Learning Rate  : 0.00013815039801161723
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [38/40] | Batch [100/1250] | Batch Loss: 0.0687
# Epoch [38/40] | Batch [200/1250] | Batch Loss: 0.0539
# Epoch [38/40] | Batch [300/1250] | Batch Loss: 0.0545
# Epoch [38/40] | Batch [400/1250] | Batch Loss: 0.0122
# Epoch [38/40] | Batch [500/1250] | Batch Loss: 0.1806
# Epoch [38/40] | Batch [600/1250] | Batch Loss: 0.0127
# Epoch [38/40] | Batch [700/1250] | Batch Loss: 0.1069
# Epoch [38/40] | Batch [800/1250] | Batch Loss: 0.0370
# Epoch [38/40] | Batch [900/1250] | Batch Loss: 0.1094
# Epoch [38/40] | Batch [1000/1250] | Batch Loss: 0.0579
# Epoch [38/40] | Batch [1100/1250] | Batch Loss: 0.0090
# Epoch [38/40] | Batch [1200/1250] | Batch Loss: 0.0067
# ======================================
# Epoch [38/40] zakończona
# Train Loss     : 0.0541
# Train Accuracy : 98.32%
# Val Loss       : 0.2535
# Val Accuracy   : 92.41%
# Learning Rate  : 6.155829702431172e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [39/40] | Batch [100/1250] | Batch Loss: 0.1089
# Epoch [39/40] | Batch [200/1250] | Batch Loss: 0.0162
# Epoch [39/40] | Batch [300/1250] | Batch Loss: 0.0365
# Epoch [39/40] | Batch [400/1250] | Batch Loss: 0.1003
# Epoch [39/40] | Batch [500/1250] | Batch Loss: 0.0255
# Epoch [39/40] | Batch [600/1250] | Batch Loss: 0.0633
# Epoch [39/40] | Batch [700/1250] | Batch Loss: 0.0078
# Epoch [39/40] | Batch [800/1250] | Batch Loss: 0.0145
# Epoch [39/40] | Batch [900/1250] | Batch Loss: 0.0562
# Epoch [39/40] | Batch [1000/1250] | Batch Loss: 0.0090
# Epoch [39/40] | Batch [1100/1250] | Batch Loss: 0.0133
# Epoch [39/40] | Batch [1200/1250] | Batch Loss: 0.2128
# ======================================
# Epoch [39/40] zakończona
# Train Loss     : 0.0502
# Train Accuracy : 98.45%
# Val Loss       : 0.2611
# Val Accuracy   : 91.83%
# Learning Rate  : 1.5413331334360186e-05
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [40/40] | Batch [100/1250] | Batch Loss: 0.0274
# Epoch [40/40] | Batch [200/1250] | Batch Loss: 0.0647
# Epoch [40/40] | Batch [300/1250] | Batch Loss: 0.0697
# Epoch [40/40] | Batch [400/1250] | Batch Loss: 0.0263
# Epoch [40/40] | Batch [500/1250] | Batch Loss: 0.0590
# Epoch [40/40] | Batch [600/1250] | Batch Loss: 0.0069
# Epoch [40/40] | Batch [700/1250] | Batch Loss: 0.0035
# Epoch [40/40] | Batch [800/1250] | Batch Loss: 0.0248
# Epoch [40/40] | Batch [900/1250] | Batch Loss: 0.0344
# Epoch [40/40] | Batch [1000/1250] | Batch Loss: 0.0515
# Epoch [40/40] | Batch [1100/1250] | Batch Loss: 0.0402
# Epoch [40/40] | Batch [1200/1250] | Batch Loss: 0.0450
# ======================================
# Epoch [40/40] zakończona
# Train Loss     : 0.0503
# Train Accuracy : 98.48%
# Val Loss       : 0.2550
# Val Accuracy   : 92.21%
# Learning Rate  : 0.0
# ======================================
# Brak poprawy. Counter: 2/5
# ======================================
# KONIEC TRENINGU
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )

# %%
# EWALUACJA


model.eval()

correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total

print("======================================")
print(f"Accuracy: {accuracy:.2f}%")
print("======================================")
# Out:
# ======================================
# Accuracy: 93.31%
# ======================================

# %%
# ============================================================
# ZAPIS WYNIKÓW DO EXCELA
# ============================================================

from datetime import datetime

new_result = {
    "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "Dataset": DATASET_NAME,
    "Batch Size": BATCH_SIZE,
    "Max Epochs": EPOCHS,
    "Executed Epochs": epoch + 1,
    "Learning Rate": LEARNING_RATE,
    "Patience": PATIENCE,
    "Train Accuracy": round(train_accuracy, 2),
    "Validation Accuracy": round(val_accuracy, 2),
    "Test Accuracy": round(accuracy, 2),
    "Best Validation Loss": round(best_val_loss, 4),
    "Model Path": MODEL_SAVE_PATH,
    "Device": str(device)
}

# ============================================================
# ODCZYT ISTNIEJĄCEGO PLIKU
# ============================================================

if os.path.exists(RESULTS_TO_EXCEL):

    try:

        df_existing = pd.read_excel(RESULTS_TO_EXCEL)

        df_new = pd.concat(
            [df_existing, pd.DataFrame([new_result])],
            ignore_index=True
        )

    except Exception as e:

        print("Błąd odczytu Excela:", e)

        print("Tworzenie nowego pliku Excel...")

        df_new = pd.DataFrame([new_result])

else:

    df_new = pd.DataFrame([new_result])

# ============================================================
# ZAPIS EXCEL
# ============================================================

try:

    df_new.to_excel(RESULTS_TO_EXCEL, index=False)

    print("======================================")
    print(f"Wyniki zapisane do: {RESULTS_TO_EXCEL}")
    print("======================================")

except Exception as e:

    print("======================================")
    print("BŁĄD ZAPISU EXCEL")
    print(e)
    print("======================================")
# Out:
# ======================================
# Wyniki zapisane do: training_results.xlsx
# ======================================

# %%
# ============================================================
# ZAPIS MODELU
# ============================================================

checkpoint = {
    "epoch": epoch + 1,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_val_loss": best_val_loss,
    "dataset": DATASET_NAME,
    "batch_size": BATCH_SIZE,
    "learning_rate": LEARNING_RATE,
}

torch.save(checkpoint, MODEL_SAVE_PATH_CHECKPOINT)

print("======================================")
print(f"Model zapisany do: {MODEL_SAVE_PATH_CHECKPOINT}")
print("======================================")
# Out:
# ======================================
# Model zapisany do: models/t_checkpoint_cifar10_32batch_40epochs_0.01lr.pth
# ======================================
